# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
x = np.linspace(1,5,10000)
A = 25647.0437921894

B = 0.47869017319

C = 0.000331169824804821

D = -277.900362668307

temp = np.power(x/C,B)
y = (A-D)/(1+temp)+D
fig = plt.plot(x,y)
plt.show()

# %%
arr = np.array([1, 2, 3, 4, 5])
t1 = time.time()
for i in range(100):
    sum = np.linalg.norm(arr, ord=2)
t2 = time.time()
print(t2-t1, sum**2)
# Out:
# 55.0
